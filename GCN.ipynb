# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshaykumarmundrathi/GCN/blob/main/GCN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip GCN_export.zip
# Out:
# Archive:  GCN_export.zip
# replace data/cora/cora.cites? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: data/cora/cora.cites
# replace data/cora/cora.content? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: data/cora/cora.content
# replace data/cora/README? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: data/cora/README

# %%
import numpy as np
import scipy.sparse as sp
import torch

# %%
def encode_onehot(labels):
    classes = set(labels)
    classes_dict = {c: np.identity(len(classes))[i, :] for i, c in enumerate(classes)}
    labels_onehot = np.array(list(map(classes_dict.get, labels)), dtype=np.int32)
    return labels_onehot

# %%
def feature_normalize(mx):
    """Row-normalize sparse matrix"""
    rowsum = np.array(mx.sum(1))
    r_inv = np.power(rowsum, -1).flatten()
    r_inv[np.isinf(r_inv)] = 0.
    r_mat_inv = sp.diags(r_inv)
    mx = r_mat_inv.dot(mx)
    return mx

# %%
def adj_normalize(mx):
    """Row-normalize sparse matrix"""
    rowsum = np.array(mx.sum(1)) # Sum each row
    r_inv = np.power(rowsum, -1/2).flatten() # Negative square root
#     r_inv[np.isinf(r_inv)] = 0.
    r_mat_inv = sp.diags(r_inv) # Create diagonal matrix

    # D^(-1/2).A.D^(-1/2)
    mx = r_mat_inv.dot(mx)
    mx = mx.dot(r_mat_inv)
    return mx

# %%
def sparse_mx_to_torch_sparse_tensor(sparse_mx):
    """Convert a scipy sparse matrix to a torch sparse tensor."""
    sparse_mx = sparse_mx.tocoo().astype(np.float32)
    indices = torch.from_numpy(
        np.vstack((sparse_mx.row, sparse_mx.col)).astype(np.int64))
    values = torch.from_numpy(sparse_mx.data)
    shape = torch.Size(sparse_mx.shape)
    return torch.sparse.FloatTensor(indices, values, shape)

# %%
def load_data(path="/content/data/cora/", dataset="cora"):

    """Load citation network dataset (cora only for now)"""
    print('Loading {} dataset...'.format(dataset))

    idx_features_labels = np.genfromtxt("{}{}.content".format(path, dataset),
                                        dtype=np.dtype(str))
    features = sp.csr_matrix(idx_features_labels[:, 1:-1], dtype=np.float32) # Processing features into a sparse matrix
    labels = encode_onehot(idx_features_labels[:, -1]) # one-hot encoding the labels


    # build graph
    idx = np.array(idx_features_labels[:, 0], dtype=np.int32) # Reading node-ids
    idx_map = {j: i for i, j in enumerate(idx)} # Creating index for nodes to map it in adjacency matrix

    edges_unordered = np.genfromtxt("{}{}.cites".format(path, dataset),
                                    dtype=np.int32) # Reading edges
    edges = np.array(list(map(idx_map.get, edges_unordered.flatten())),
                     dtype=np.int32).reshape(edges_unordered.shape) # Mapping node-ids in the edge list to the index

    # Build adjacency matrix
    adj = sp.coo_matrix((np.ones(edges.shape[0]), (edges[:, 0], edges[:, 1])),
                        shape=(labels.shape[0], labels.shape[0]),
                        dtype=np.float32)

    # CHECK OUT THE DIFFERENCES BETWEEN csr_matrix (features) and coo_matrix (adj)

    # Normalizing features
    features = feature_normalize(features)

#     # build symmetric adjacency matrix
#     adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj)

#     Normalizing the adjacency matrix after adding self loops
    adj = adj_normalize(adj + sp.eye(adj.shape[0]))

    # Setting training, validation, and test range
    idx_train = range(140)
    idx_val = range(200, 500)
    idx_test = range(500, 1500)

    # Converting all matrices into pytorch tensors
    features = torch.FloatTensor(np.array(features.todense()))
    labels = torch.LongTensor(np.where(labels)[1])
    adj = sparse_mx_to_torch_sparse_tensor(adj)

    idx_train = torch.LongTensor(idx_train)
    idx_val = torch.LongTensor(idx_val)
    idx_test = torch.LongTensor(idx_test)

    return adj, features, labels, idx_train, idx_val, idx_test

# %%
# Function to find accuracy from two tensors
def accuracy(output, labels):
    preds = output.max(1)[1].type_as(labels) # Get the index of maximum value of 1 dimension and typecast to labels datatype
    correct = preds.eq(labels).double() # Convert into double
    correct = correct.sum() # Sum correct predictions
    return correct / len(labels)

# %%
import math

from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module

# Class to define a neural network layer that inherits PyTorch Module
# Check out documentaion of the base class 'Module' at:
# https://pytorch.org/docs/stable/generated/torch.nn.Module.html
class GraphConvolution(Module):
    # Each layer requires no. of input features, no. of output features, and optional bias
    def __init__(self, in_feat, out_feat, bias=True):
        super(GraphConvolution, self).__init__()

        self.in_features = in_feat
        self.out_features = out_feat

        # Using Parameter to automatically add weights and bias to learnable parameters
        #THIS WILL BE USEFUL ONLY WHEN WE USE Module in the model
        self.weight = Parameter(torch.FloatTensor(in_feat, out_feat))

        if bias:
            self.bias = Parameter(torch.FloatTensor(out_feat))
        else:
            self.register_parameter('bias', None)

        self.reset_parameters()

    # Function to get uniform distribution of weights and bias values
    # Can be removed if necessary
    def reset_parameters(self):
        stdv = 1. / math.sqrt(self.weight.size(1))
        self.weight.data.uniform_(-stdv, stdv)

        if self.bias is not None:
            self.bias.data.uniform_(-stdv, stdv)

    # Forward function where it actually requires the input data and operations
    def forward(self, inp, adj):
        # Basically we multiply A.H,W
        support = torch.mm(inp, self.weight)
        output = torch.spmm(adj, support)

        # Adding bias if true
        if self.bias is not None:
            return output + self.bias
        else:
            return output

# %%
import torch.nn as nn
import torch.nn.functional as F

# Class to define the model architecture
class GCN(nn.Module):
    # The model needs no. of input features, no. of hidden units,
    # no. of classes, and optional dropout

    # NOTE: We use a simply model with one hidden layer
        # Architecture will change for deep models
        # Ideally, we keep only a few layers in most GNNs
    def __init__(self, nfeat, nhid, nclass, dropout):
        super(GCN, self).__init__()

        # Defining one hidden layer and one output layer
        self.gcn1 = GraphConvolution(nfeat, nhid)
        self.gcn2 = GraphConvolution(nhid, nclass)
        self.dropout = dropout

    # Similar to GraphConvolution, we give required input data to the forward function
    # And specify operations - here it is activation and dropout
    def forward(self, x, adj):
        x = F.relu(self.gcn1(x, adj)) # Applying non-linearity on hidden layer 1
        # Checkout difference between nn.Dropout() and F.dropout()
        x = F.dropout(x, self.dropout, training=self.training)
        x = self.gcn2(x, adj)
        return F.log_softmax(x, dim=1) # Applying lograthmic softmax on output layer

# %%
import torch.optim as optim

adj, features, labels, train_ids, val_ids, test_ids = load_data()

# Model and optimizer
model = GCN(nfeat=features.shape[1],
            nhid=16,
            nclass=labels.max().item() + 1,
            dropout=0.5)

# Using Adam optimizer. Other optimizer can be used too
optimizer = optim.Adam(model.parameters(),
                       lr=0.01, weight_decay=5e-4)
# Out:
# Loading cora dataset...
# /tmp/ipython-input-19-3650411315.py:8: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:644.)
#   return torch.sparse.FloatTensor(indices, values, shape)

# %%
# Code for GPU computing

# CHANGE THIS CODE TO SUIT YOUR VERSION OF PYTORCH. THE SYNTAX OF THIS COULD VARY SIGNIFICANTLY

# If cuda is available, movie all data to gpu
# And preparing for CUDA operations
if torch.cuda.is_available():
    model.cuda()
    features = features.cuda()
    adj = adj.cuda()
    labels = labels.cuda()
    train_ids.cuda()
    val_ids.cuda()
    test_ids.cuda()

# %%
import time

def train(epoch):
    t = time.time()

    # Evaluating the model in training mode
    model.train()
    optimizer.zero_grad() # Reseting gradient at each layer to avoid exploding gradient problem
    output = model(features, adj)
     # Optimizing with nll_loss. Other losses like cross_entropy can also be used
    loss_train = F.nll_loss(output[train_ids], labels[train_ids])
    acc_train = accuracy(output[train_ids], labels[train_ids])
    # backprop and optimize model parameters
    # Not needed to specify parameters when using Parameter
    loss_train.backward()
    optimizer.step()

    # Evaluating validation performance separately
    model.eval()
    output = model(features, adj)
    loss_val = F.nll_loss(output[val_ids], labels[val_ids])
    acc_val = accuracy(output[val_ids], labels[val_ids])


    loss_val = F.nll_loss(output[val_ids], labels[val_ids])
    acc_val = accuracy(output[val_ids], labels[val_ids])

    print('Epoch: {:04d}'.format(epoch+1),
          'loss_train: {:.4f}'.format(loss_train.item()),
          'acc_train: {:.4f}'.format(acc_train.item()),
          'loss_val: {:.4f}'.format(loss_val.item()),
          'acc_val: {:.4f}'.format(acc_val.item()),
          'time: {:.4f}s'.format(time.time() - t))

# %%
# Function to test the model

"""
def test():
    model.eval()
    output = model(features, adj)
    loss_test = F.nll_loss(output[test_ids], labels[test_ids])
    acc_test = accuracy(output[test_ids], labels[test_ids])


    print("Test set results:",
          "loss= {:.4f}".format(loss_test.item()),
          "accuracy= {:.4f}".format(acc_test.item()))
"""

from sklearn.metrics import precision_score, recall_score, f1_score

def test():
    model.eval()
    with torch.no_grad():
        output = model(features, adj)
        loss_test = F.nll_loss(output[test_ids], labels[test_ids])
        acc_test = accuracy(output[test_ids], labels[test_ids])

        _, predicted = torch.max(output[test_ids], 1)

        # Moving the data to CPU for sklearn metrics calculation
        predicted_np = predicted.cpu().numpy()
        labels_np = labels[test_ids].cpu().numpy()

        precision = precision_score(labels_np, predicted_np, average='weighted')
        recall = recall_score(labels_np, predicted_np, average='weighted')
        f1 = f1_score(labels_np, predicted_np, average='weighted')

        print(f"Test set results: loss= {loss_test.item():.4f}, accuracy= {acc_test:.4f}, precision= {precision:.4f}, recall= {recall:.4f}, F1 Score= {f1:.4f}")

# %%
t_total = time.time()

for epoch in range(200):
    train(epoch)

print()
print('Optimization finished...')
print('Total time elapsed: {:.4f}s'.format(time.time() - t_total))

test()
# Out:
# Epoch: 0001 loss_train: 1.9408 acc_train: 0.2429 loss_val: 1.9047 acc_val: 0.3367 time: 0.1086s
# Epoch: 0002 loss_train: 1.9095 acc_train: 0.3429 loss_val: 1.8858 acc_val: 0.3400 time: 0.0193s
# Epoch: 0003 loss_train: 1.8680 acc_train: 0.3357 loss_val: 1.8695 acc_val: 0.3400 time: 0.0180s
# Epoch: 0004 loss_train: 1.8412 acc_train: 0.3714 loss_val: 1.8559 acc_val: 0.3467 time: 0.0183s
# Epoch: 0005 loss_train: 1.8372 acc_train: 0.3286 loss_val: 1.8439 acc_val: 0.3467 time: 0.0182s
# Epoch: 0006 loss_train: 1.8128 acc_train: 0.3429 loss_val: 1.8331 acc_val: 0.3467 time: 0.0213s
# Epoch: 0129 loss_train: 0.3478 acc_train: 0.9429 loss_val: 1.0316 acc_val: 0.7000 time: 0.0175s
# Epoch: 0130 loss_train: 0.3399 acc_train: 0.9571 loss_val: 1.0304 acc_val: 0.7000 time: 0.0188s
# Epoch: 0131 loss_train: 0.3303 acc_train: 0.9643 loss_val: 1.0286 acc_val: 0.7000 time: 0.0180s
# Epoch: 0132 loss_train: 0.3592 acc_train: 0.9143 loss_val: 1.0270 acc_val: 0.7000 time: 0.0175s
# Epoch: 0133 loss_train: 0.3034 acc_train: 0.9714 loss_val: 1.0249 acc_val: 0.7000 time: 0.0180s
# Epoch: 0134 loss_train: 0.3795 acc_train: 0.9286 loss_val: 1.0220 acc_val: 0.7000 time: 0.0212s
# Epoch: 0135 loss_train: 0.3001 acc_train: 0.9643 loss_val: 1.0198 acc_val: 0.7033 time: 0.0192s
# Epoch: 0136 loss_train: 0.3331 acc_train: 0.9143 loss_val: 1.0186 acc_val: 0.7000 time: 0.0171s
# Epoch: 0137 loss_train: 0.3919 acc_train: 0.9214 loss_val: 1.0190 acc_val: 0.6967 time: 0.0184s
# Epoch: 0138 loss_train: 0.3430 acc_train: 0.9429 loss_val: 1.0208 acc_val: 0.7100 time: 0.0184s
# Epoch: 0139 loss_train: 0.3055 acc_train: 0.9429 loss_val: 1.0235 acc_val: 0.7167 time: 0.0179s
# Epoch: 0140 loss_train: 0.2592 acc_train: 0.9786 loss_val: 1.0246 acc_val: 0.7133 time: 0.0182s
# Epoch: 0141 loss_train: 0.3140 acc_train: 0.9429 loss_val: 1.0245 acc_val: 0.7033 time: 0.0193s
# Epoch: 0142 loss_train: 0.3160 acc_train: 0.9500 loss_val: 1.0231 acc_val: 0.7033 time: 0.0187s
# Epoch: 0143 loss_train: 0.3789 acc_train: 0.9143 loss_val: 1.0216 acc_val: 0.6967 time: 0.0186s
# Epoch: 0144 loss_train: 0.2630 acc_train: 0.9714 loss_val: 1.0199 acc_val: 0.6967 time: 0.0184s
# Epoch: 0145 loss_train: 0.3082 acc_train: 0.9500 loss_val: 1.0192 acc_val: 0.6967 time: 0.0193s
# Epoch: 0146 loss_train: 0.3346 acc_train: 0.9429 loss_val: 1.0175 acc_val: 0.7000 time: 0.0189s
# Epoch: 0147 loss_train: 0.3177 acc_train: 0.9429 loss_val: 1.0170 acc_val: 0.7000 time: 0.0187s
# Epoch: 0148 loss_train: 0.2770 acc_train: 0.9500 loss_val: 1.0172 acc_val: 0.7067 time: 0.0182s
# Epoch: 0149 loss_train: 0.3219 acc_train: 0.9571 loss_val: 1.0182 acc_val: 0.7100 time: 0.0169s
# Epoch: 0150 loss_train: 0.3132 acc_train: 0.9429 loss_val: 1.0186 acc_val: 0.7167 time: 0.0174s
# Epoch: 0151 loss_train: 0.3414 acc_train: 0.9214 loss_val: 1.0181 acc_val: 0.7200 time: 0.0173s
# Epoch: 0152 loss_train: 0.2904 acc_train: 0.9571 loss_val: 1.0174 acc_val: 0.7200 time: 0.0175s
# Epoch: 0153 loss_train: 0.3254 acc_train: 0.9643 loss_val: 1.0178 acc_val: 0.7200 time: 0.0180s
# Epoch: 0154 loss_train: 0.3058 acc_train: 0.9500 loss_val: 1.0196 acc_val: 0.7167 time: 0.0174s
# Epoch: 0155 loss_train: 0.2820 acc_train: 0.9786 loss_val: 1.0197 acc_val: 0.7133 time: 0.0189s
# Epoch: 0156 loss_train: 0.3208 acc_train: 0.9357 loss_val: 1.0193 acc_val: 0.7100 time: 0.0242s
# Epoch: 0157 loss_train: 0.2991 acc_train: 0.9429 loss_val: 1.0176 acc_val: 0.7067 time: 0.0250s
# Epoch: 0158 loss_train: 0.3390 acc_train: 0.9571 loss_val: 1.0156 acc_val: 0.7033 time: 0.0193s
# Epoch: 0159 loss_train: 0.3113 acc_train: 0.9714 loss_val: 1.0133 acc_val: 0.7100 time: 0.0176s
# Epoch: 0160 loss_train: 0.2338 acc_train: 0.9643 loss_val: 1.0118 acc_val: 0.7100 time: 0.0196s
# Epoch: 0161 loss_train: 0.3292 acc_train: 0.9571 loss_val: 1.0097 acc_val: 0.7067 time: 0.0183s
# Epoch: 0162 loss_train: 0.2725 acc_train: 0.9714 loss_val: 1.0096 acc_val: 0.7067 time: 0.0189s
# Epoch: 0163 loss_train: 0.2982 acc_train: 0.9714 loss_val: 1.0103 acc_val: 0.7067 time: 0.0189s
# Epoch: 0164 loss_train: 0.2451 acc_train: 0.9714 loss_val: 1.0127 acc_val: 0.7133 time: 0.0207s
# Epoch: 0165 loss_train: 0.2819 acc_train: 0.9500 loss_val: 1.0137 acc_val: 0.7133 time: 0.0208s
# Epoch: 0166 loss_train: 0.3174 acc_train: 0.9357 loss_val: 1.0136 acc_val: 0.7167 time: 0.0193s
# Epoch: 0167 loss_train: 0.2755 acc_train: 0.9643 loss_val: 1.0123 acc_val: 0.7167 time: 0.0220s
# Epoch: 0168 loss_train: 0.2930 acc_train: 0.9500 loss_val: 1.0111 acc_val: 0.7167 time: 0.0181s
# Epoch: 0169 loss_train: 0.2933 acc_train: 0.9571 loss_val: 1.0099 acc_val: 0.7200 time: 0.0180s
# Epoch: 0170 loss_train: 0.3181 acc_train: 0.9286 loss_val: 1.0090 acc_val: 0.7133 time: 0.0186s
# Epoch: 0171 loss_train: 0.3113 acc_train: 0.9643 loss_val: 1.0090 acc_val: 0.7100 time: 0.0183s
# Epoch: 0172 loss_train: 0.2969 acc_train: 0.9571 loss_val: 1.0082 acc_val: 0.7100 time: 0.0180s
# Epoch: 0173 loss_train: 0.2844 acc_train: 0.9429 loss_val: 1.0064 acc_val: 0.7100 time: 0.0186s
# Epoch: 0174 loss_train: 0.2867 acc_train: 0.9429 loss_val: 1.0048 acc_val: 0.7033 time: 0.0203s
# Epoch: 0175 loss_train: 0.2667 acc_train: 0.9571 loss_val: 1.0042 acc_val: 0.7067 time: 0.0184s
# Epoch: 0176 loss_train: 0.2637 acc_train: 0.9571 loss_val: 1.0047 acc_val: 0.7067 time: 0.0178s
# Epoch: 0177 loss_train: 0.2990 acc_train: 0.9571 loss_val: 1.0051 acc_val: 0.7067 time: 0.0183s
# Epoch: 0178 loss_train: 0.2785 acc_train: 0.9500 loss_val: 1.0058 acc_val: 0.7100 time: 0.0200s
# Epoch: 0179 loss_train: 0.3098 acc_train: 0.9714 loss_val: 1.0070 acc_val: 0.7067 time: 0.0180s
# Epoch: 0180 loss_train: 0.3016 acc_train: 0.9429 loss_val: 1.0076 acc_val: 0.7067 time: 0.0183s
# Epoch: 0181 loss_train: 0.2637 acc_train: 0.9500 loss_val: 1.0083 acc_val: 0.7067 time: 0.0178s
# Epoch: 0182 loss_train: 0.2707 acc_train: 0.9500 loss_val: 1.0091 acc_val: 0.7100 time: 0.0178s
# Epoch: 0183 loss_train: 0.2894 acc_train: 0.9571 loss_val: 1.0075 acc_val: 0.7100 time: 0.0178s
# Epoch: 0184 loss_train: 0.2698 acc_train: 0.9643 loss_val: 1.0059 acc_val: 0.7067 time: 0.0174s
# Epoch: 0185 loss_train: 0.2955 acc_train: 0.9500 loss_val: 1.0050 acc_val: 0.7100 time: 0.0170s
# Epoch: 0186 loss_train: 0.2977 acc_train: 0.9571 loss_val: 1.0042 acc_val: 0.7133 time: 0.0172s
# Epoch: 0187 loss_train: 0.2774 acc_train: 0.9429 loss_val: 1.0043 acc_val: 0.7100 time: 0.0175s
# Epoch: 0188 loss_train: 0.2813 acc_train: 0.9429 loss_val: 1.0062 acc_val: 0.7067 time: 0.0175s
# Epoch: 0189 loss_train: 0.3169 acc_train: 0.9429 loss_val: 1.0089 acc_val: 0.7133 time: 0.0176s
# Epoch: 0190 loss_train: 0.2722 acc_train: 0.9571 loss_val: 1.0115 acc_val: 0.7100 time: 0.0198s
# Epoch: 0191 loss_train: 0.2713 acc_train: 0.9571 loss_val: 1.0135 acc_val: 0.7000 time: 0.0201s
# Epoch: 0192 loss_train: 0.2582 acc_train: 0.9500 loss_val: 1.0132 acc_val: 0.7033 time: 0.0188s
# Epoch: 0193 loss_train: 0.2931 acc_train: 0.9286 loss_val: 1.0110 acc_val: 0.7000 time: 0.0204s
# Epoch: 0194 loss_train: 0.2629 acc_train: 0.9571 loss_val: 1.0082 acc_val: 0.7033 time: 0.0185s
# Epoch: 0195 loss_train: 0.2559 acc_train: 0.9643 loss_val: 1.0044 acc_val: 0.7067 time: 0.0191s
# Epoch: 0196 loss_train: 0.2881 acc_train: 0.9643 loss_val: 1.0013 acc_val: 0.7100 time: 0.0188s
# Epoch: 0197 loss_train: 0.2365 acc_train: 0.9571 loss_val: 0.9998 acc_val: 0.7100 time: 0.0189s
# Epoch: 0198 loss_train: 0.2474 acc_train: 0.9714 loss_val: 1.0005 acc_val: 0.7100 time: 0.0178s
# Epoch: 0199 loss_train: 0.2683 acc_train: 0.9714 loss_val: 1.0021 acc_val: 0.7100 time: 0.0177s
# Epoch: 0200 loss_train: 0.2801 acc_train: 0.9429 loss_val: 1.0036 acc_val: 0.7100 time: 0.0190s
#
# Optimization finished...
# Total time elapsed: 3.8817s
# Test set results: loss= 1.0536, accuracy= 0.6570, precision= 0.6762, recall= 0.6570, F1 Score= 0.6532

# %% [markdown]
# ###
